# %% [markdown]
# <a href="https://colab.research.google.com/github/italobotelho/PI2026.1/blob/main/03_EDA_e_Integracao_MongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧬 **Projeto SIEST: Sistema de Inteligência Epidemiológica e Socioespacial**
# ## Notebook 03: Análise Exploratória (EDA) e Integração MongoDB (Camada Gold)
